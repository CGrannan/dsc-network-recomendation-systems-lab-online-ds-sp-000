# %% [markdown]
# # Amazon Recommendation System - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and build a recommendation system for a real world dataset! For this lab, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# In this lab you will:
#
# - Use graph-based similarity metrics to create a collaborative filtering recommender system

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd
import networkx as nx
G = nx.Graph()

df = pd.read_csv('books_data.edgelist', names=['source', 'target', 'weight'], delimiter=' ')
df.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %% [markdown]
# ## Load the Metadata
#
# Import the metadata available in the file `'books_meta.txt'` (note it is `'\t'` seperated).

# %%
metadata = pd.read_csv('books_meta.txt', delimiter='\t')
metadata.head()
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  SalesRank  \
# 0  clergi sermon subject religion preach spiritu ...  Book     396585
# 1  subject witchcraft earth religion spiritu base...  Book     168596
# 2       general hobbi subject craft home garden book  Book    1270652
# 3  spiritu translat commentari christian book gui...  Book     631289
# 4  subject religion spiritu busi christian live w...  Book     455160
#
#    TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 0             2        5.0                 8             0.80
# 1            12        4.5                 9             0.85
# 2             1        5.0                 0             0.00
# 3             1        4.0                 6             0.79
# 4             0        0.0                 4             1.00

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
dragons = metadata[metadata.Title.str.contains('dragon')]
dragons
# Out:
#             Id        ASIN                                              Title  \
# 19991    28075  0380781042                Grail (The Pendragon Cycle, Book 5)
# 41710    58385  0380717573  Pendragon : Book Four of the Pendragon Cycle (...
# 43121    60373  1928999131          The Arthurian Companion (Pendragon, 6208)
# 68199    95111  0920336531  From Mondragon to America: Experiments in Comm...
# 92857   129437  0801433258  Values at Work: Employee Participation Meets M...
# 96152   133931  0743437314        The Merchant of Death (Pendragon Series #1)
# 103715  144586  0875461824  Making Mondragon: The Growth and Dynamics of t...
# 113866  158778  0743437322        The Lost City of Faar (Pendragon Series #2)
# 113890  158812  0764546511  The Offical Pendragon Forms¿ For Palm OS® Star...
# 125283  174764  0877736111  Rumi's World : The Life and Works of the Great...
# 131735  183786  0743437330                The Never War (Pendragon Series #3)
# 167028  232832  0380708906               Arthur (The Pendragon Cycle, Book 3)
# 183476  255667  038070613X  Taliesin : Book One of the Pendragon Cycle (Pe...
# 191526  266935  0380708892              Merlin (The Pendragon Cycle , Book 2)
# 238419  330895  1570360669   Caleb Beldragons Chronicle of the Three Counties
# 246749  342260  0380708795             On the Devil's Court (Pendragon Cycle)
# 339331  468061  051513225X                                          Pendragon
# 358537  494257  1928999190  Legends of the Pendragon (Pendragon Fiction, 6...
#
#                                                Categories Group  SalesRank  \
# 19991   subject stephen author l epic z fantasi histor...  Book      38590
# 41710   general subject stephen author l epic z fantas...  Book      39704
# 43121   general subject arthurian ann literatur phylli...  Book     578570
# 68199   growth event general biographi subject current...  Book     530770
# 92857   behavior busi technic sociolog book com labor ...  Book    1184228
# 96152   literatur action book hamster fiction general ...  Book      22160
# 103715  general nonfict subject sociolog social book s...  Book     616136
# 113866  adventur subject literatur monkey magic action...  Book      11151
# 113890  databas os general subject system palm api int...  Book     747165
# 125283  art general biographi subject religion literat...  Book     198111
# 131735  adventur subject literatur magic action horror...  Book      24044
# 167028  general subject stephen literatur author l epi...  Book     150568
# 183476  general subject stephen literatur author l epi...  Book      65485
# 191526  general subject stephen literatur author l epi...  Book      82775
# 238419  subject specialti unknown fantasi book scienc ...  Book    1634053
# 246749        general subject literatur book teen fiction  Book      48103
# 339331  general subject author c z paperback coulter h...  Book      75503
# 358537  legend general subject arthurian literatur wor...  Book    1060807
#
#         TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 19991             30        3.5                12             0.52
# 41710             13        4.0                11             0.64
# 43121              4        5.0                 1             0.00
# 68199              0        0.0                 2             1.00
# 92857              1        5.0                 3             0.58
# 96152             91        5.0                 9             0.20
# 103715             0        0.0                 2             1.00
# 113866            28        5.0                 1             0.00
# 113890             4        3.5                 0             0.00
# 125283             5        5.0                 8             0.42
# 131735            11        5.0                 1             0.00
# 167028            27        4.5                 9             0.79
# 183476            75        4.0                 8             0.68
# 191526            35        4.5                 5             0.71
# 238419             2        5.0                 0             0.00
# 246749            19        4.5                 9             0.82
# 339331            32        3.5                 8             0.76
# 358537             1        3.0                 0             0.00

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# The `'books_data.edgelist'` has conveniently already calculated the distance between items for you. Given this preprocessed data, it's time to employ collaborative filtering to generate recommendations! Generate the top 10 recommendations for each book in the subset you chose. Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
rec_dict = {}
id_name_dict = dict(zip(metadata.ASIN, metadata.Title))
for row in dragons.index:
    book_id = dragons.ASIN[row]
    book_name = id_name_dict[book_id]
    most_similar = df[(df.source == book_id)
                      | (df.target == book_id)
                     ].sort_values(by='weight', ascending=False).head(10)
    most_similar['source_name'] = most_similar['source'].map(id_name_dict)
    most_similar['target_name'] = most_similar['target'].map(id_name_dict)
    recommendations = []
    for row in most_similar.index:
        if most_similar.source[row] == book_id:
            recommendations.append((most_similar.target_name[row], most_similar.weight[row]))
        else:
            recommendations.append((most_similar.source_name[row], most_similar.weight[row]))
    rec_dict[book_name] = recommendations
    print('Recommendations for:', book_name)
    for r in recommendations:
        print(r)
    print('\n\n')
# Out:
# Recommendations for: Grail (The Pendragon Cycle, Book 5)
# ('The Silver Hand: Song of Albion Book 2 (Song of Albion Trilogy)', 0.77)
# ('The Dragon King Saga: In the Hall of the Dragon King, The Warlords of Nin, and The Sword and the Flame', 0.77)
# ('The Paradise War (Song of Albion, Volume 1)', 0.77)
# ('The Paradise War: Song of Albion Book 1 (Song of Albion Trilogy)', 0.77)
# ('Merlin (The Pendragon Cycle , Book 2)', 0.75)
# ('Taliesin : Book One of the Pendragon Cycle (Pendragon Cycle (Paperback))', 0.75)
# ('Arthur (The Pendragon Cycle, Book 3)', 0.75)
# ('The Iron Lance (The Celtic Crusades, Book 1)', 0.73)
# ('Avalon: : The Return of King Arthur', 0.67)
# ('The Silver Hand (Song of Albion, Volume 2)', 0.67)
#
#
#
# Recommendations for: Pendragon : Book Four of the Pendragon Cycle (Pendragon Cycle, No 4)
# ('The Paradise War: Song of Albion Book 1 (Song of Albion Trilogy)', 0.85)
# ('Taliesin : Book One of the Pendragon Cycle (Pendragon Cycle (Paperback))', 0.81)
# ('Merlin (The Pendragon Cycle , Book 2)', 0.81)
# ('Black Rood, The', 0.8)
# ('Mystic Rose, The', 0.8)
# ('The Iron Lance (The Celtic Crusades, Book 1)', 0.8)
# ('Avalon: : The Return of King Arthur', 0.72)
# ('Merlin', 0.67)
# ('The Iron Lance (The Celtic Crusades, Book 1)', 0.63)
# ('The Iron Lance (The Celtic Crusades, Book 1)', 0.21)
#
#
#
# Recommendations for: The Arthurian Companion (Pendragon, 6208)
# ('The World of King Arthur', 0.27)
#
#
#
# Recommendations for: From Mondragon to America: Experiments in Community Economic Development
# ('Values at Work: Employee Participation Meets Market Pressure at Mondragon', 0.48)
# ('Making Mondragon: The Growth and Dynamics of the Worker Cooperative Complex (Cornell International Industrial and Labor Relations Report)', 0.12)
#
#
#
# Recommendations for: Values at Work: Employee Participation Meets Market Pressure at Mondragon
# ('From Mondragon to America: Experiments in Community Economic Development', 0.48)
# ('The Working Life : The Promise and Betrayal of Modern Work', 0.44)
# ('Making Mondragon: The Growth and Dynamics of the Worker Cooperative Complex (Cornell International Industrial and Labor Relations Report)', 0.24)
#
#
#
# Recommendations for: The Merchant of Death (Pendragon Series #1)
# ('The Never War (Pendragon Series #3)', 0.67)
# ('The Lost City of Faar (Pendragon Series #2)', 0.65)
# ('Broken Sky Series #05 (Broken Sky)', 0.59)
# ('Broken Sky (Broken Sky)', 0.59)
# ('Broken Sky #2 (Broken Sky)', 0.59)
# ('Broken Sky Series #06 (Broken Sky)', 0.57)
# ('Broken Sky (Broken Sky)', 0.57)
# ('Lightland', 0.41)
# ('Ten Miles from Winnemucca', 0.24)
#
#
#
# Recommendations for: Making Mondragon: The Growth and Dynamics of the Worker Cooperative Complex (Cornell International Industrial and Labor Relations Report)
# ('Values at Work: Employee Participation Meets Market Pressure at Mondragon', 0.24)
# ('From Mondragon to America: Experiments in Community Economic Development', 0.12)
#
#
#
# Recommendations for: The Lost City of Faar (Pendragon Series #2)
# ('The Merchant of Death (Pendragon Series #1)', 0.65)
#
#
#
# Recommendations for: The Offical Pendragon Forms¿ For Palm OS® Starter Kit
#
#
#
# Recommendations for: Rumi's World : The Life and Works of the Greatest Sufi Poet (Shambhala dragon editions)
# ('The Life and Work of Jalaluddin Rumi', 0.57)
# ('The Rumi Collection : An Anthology of Translations of Mevlana Jalaluddin Rumi (Shambhala Classics)', 0.53)
# ('Essential Rumi', 0.5)
# ('Rumi Past and Present, East and West', 0.47)
# ('Mystical Dimensions of Islam', 0.44)
# ('The Mystical Poems of Rumi 2 : Second Selection, Poems 201-400', 0.44)
# ('The Triumphal Sun: A Study of the Works of Jalaloddinn Rumi (Persian Studies Series ; 8)', 0.33)
# ('Sexuality in Islam', 0.18)
#
#
#
# Recommendations for: The Never War (Pendragon Series #3)
# ('The Merchant of Death (Pendragon Series #1)', 0.67)
#
#
#
# Recommendations for: Arthur (The Pendragon Cycle, Book 3)
# ('Taliesin : Book One of the Pendragon Cycle (Pendragon Cycle (Paperback))', 1.0)
# ('Grail (The Pendragon Cycle, Book 5)', 0.75)
# ('The Silver Hand: Song of Albion Book 2 (Song of Albion Trilogy)', 0.69)
# ('The Endless Knot: Song of Albion Book 3 (Song of Albion Trilogy)', 0.69)
# ('The Paradise War: Song of Albion Book 1 (Song of Albion Trilogy)', 0.69)
# ('The Paradise War (Song of Albion, Volume 1)', 0.69)
# ('Avalon: : The Return of King Arthur', 0.62)
# ('The Silver Hand (Song of Albion, Volume 2)', 0.61)
# ('The Endless Knot (Song of Albion, Volume 3)', 0.61)
#
#
#
# Recommendations for: Taliesin : Book One of the Pendragon Cycle (Pendragon Cycle (Paperback))
# ('Arthur (The Pendragon Cycle, Book 3)', 1.0)
# ('Pendragon : Book Four of the Pendragon Cycle (Pendragon Cycle, No 4)', 0.81)
# ('Grail (The Pendragon Cycle, Book 5)', 0.75)
# ('The Paradise War (Song of Albion, Volume 1)', 0.69)
# ('The Paradise War: Song of Albion Book 1 (Song of Albion Trilogy)', 0.69)
# ('The Iron Lance (The Celtic Crusades, Book 1)', 0.67)
# ('Avalon: : The Return of King Arthur', 0.62)
# ('Byzantium (Harper Fiction)', 0.59)
#
#
#
# Recommendations for: Merlin (The Pendragon Cycle , Book 2)
# ('Pendragon : Book Four of the Pendragon Cycle (Pendragon Cycle, No 4)', 0.81)
# ('Grail (The Pendragon Cycle, Book 5)', 0.75)
# ('The Iron Lance (The Celtic Crusades, Book 1)', 0.67)
# ('Avalon: : The Return of King Arthur', 0.62)
# ('Byzantium (Harper Fiction)', 0.59)
#
#
#
# Recommendations for: Caleb Beldragons Chronicle of the Three Counties
#
#
#
# Recommendations for: On the Devil's Court (Pendragon Cycle)
# ('The Rebounder', 0.38)
# ('Slam! (Point Signature (Scholastic))', 0.38)
# ('Night Hoops', 0.33)
# ('Heart of a Champion (Avon Camelot Books (Paperback))', 0.3)
# ('Painting the Black (Avon Camelot Books (Paperback))', 0.3)
# ('Night Hoops', 0.29)
# ('Danger Zone (Point Signature)', 0.26)
# ('The Moves Make the Man (Newbery Honor Book)', 0.24)
# ('Hoops (Laurel Leaf Books)', 0.24)
#
#
#
# Recommendations for: Pendragon
# ('The Sherbrooke Bride (Bride Trilogy (Paperback))', 1.0)
# ('The Scottish Bride (Bride Trilogy (Paperback))', 0.93)
# ('The Courtship', 0.93)
# ('Mad Jack', 0.93)
# ('Hellion Bride (Bride Trilogy (Paperback))', 0.93)
# ('The Heiress Bride (Bride Trilogy (Paperback))', 0.87)
# ('The Hellion Bride', 0.71)
# ('The Sherbrooke Bride (Bride Trilogy (Audio))', 0.71)
#
#
#
# Recommendations for: Legends of the Pendragon (Pendragon Fiction, 6211)

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
